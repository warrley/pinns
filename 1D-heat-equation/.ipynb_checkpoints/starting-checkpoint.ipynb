# %%
import torch 
import torch.nn as nn
from torch.autograd import grad
import matplotlib.pyplot as plt

# %%
class PINN(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(2, 64),
            nn.Tanh(),

            nn.Linear(64, 64),
            nn.Tanh(),

            nn.Linear(64, 64),
            nn.Tanh(),

            nn.Linear(64, 1)
        )
    def forward(self, t, x):

        inputs = torch.cat([t, x], dim=1)

        return self.net(inputs)

# %%
def derivative(u, x):
    return grad(
        u,
        x,
        grad_outputs = torch.ones_like(u),
        create_graph=True,
        retain_graph=True
    )[0]

# %% [markdown]
# # creating the model

# %%
model = PINN()

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=1e-3
)

# %% [markdown]
# # describind pde

# %% [markdown]
# ## intern points
# #### minimize ut​−Duxx​=0

# %%
Nf = 5000

t_f = torch.rand(Nf, 1, requires_grad=True)
x_f = torch.rand(Nf, 1, requires_grad=True)

# %% [markdown]
# ## boundary conditions

# %% [markdown]
# ## x= 0
# #### u(t,0) = 1

# %%
Nb = 1000
t_b1 = torch.rand(Nb, 1, requires_grad=True)
x_b1 = torch.zeros(Nb, 1, requires_grad=True)
u_b1_true = torch.ones(Nb,1)

# %% [markdown]
# #### u(t,1) = 1

# %%
t_b2 = torch.rand(Nb,1,requires_grad=True)
x_b2 = torch.ones(Nb,1,requires_grad=True)
u_b2_true = torch.ones(Nb,1)

# %% [markdown]
# ## initial conditions
# ### u(0,x) = 0

# %%
Ni = 2000
t_i = torch.zeros(Ni, 1, requires_grad=True)
x_i = torch.rand(Ni,1,requires_grad=True)
u_i_true = torch.zeros(Ni,1)

# %% [markdown]
# # Training

# %%
a = 0.2
epochs = 8000

for epoch in range(epochs):
    optimizer.zero_grad()

    # PDE

    u_f = model(t_f, x_f)
    u_t = derivative(u_f, t_f)
    u_x = derivative(u_f, x_f)
    u_xx = derivative(u_x, x_f)

    # equation residual
    loss_pde = torch.mean((u_t - a * u_xx)**2)

    # bc conditions
    u_b1 = model(t_b1, x_b1)
    u_b2 = model(t_b2, x_b2)

    # bc residual
    loss_bc = (
        torch.mean((u_b1 - u_b1_true)**2)
        +
        torch.mean((u_b2 - u_b2_true)**2)
    )

    # initial conditions
    u_i = model(t_i, x_i)

    # initial residual
    loss_ic = torch.mean((u_i - u_i_true)**2)

    # TOTAL LOSS
    loss = (loss_pde + loss_bc + loss_ic)

    loss.backward()

    optimizer.step()

    if epoch % 1000 == 0:
        print(epoch, loss_pde.item(), loss_bc.item(), loss_ic.item(), loss.item())
# Out:
# 0 0.0009972876869142056 1.6137135028839111 0.0074591925367712975 1.6221699714660645
# 1000 0.004075723234564066 0.022390343248844147 0.026514016091823578 0.052980080246925354
# 2000 0.006712011061608791 0.011746028438210487 0.012610388919711113 0.031068427488207817
# 3000 0.001119437743909657 0.01032855361700058 0.00822069775313139 0.019668688997626305
# 4000 0.0008710427209734917 0.009079761803150177 0.007016790099442005 0.016967594623565674
# 5000 0.0014427404385060072 0.008353983983397484 0.005765550769865513 0.015562275424599648

# %% [markdown]
# # Vizualizing
# ### creating the space

# %%
nx = 200
nt = 100

x = torch.linspace(0,1,nx)
t = torch.linspace(0,1,nt)

X, T = torch.meshgrid(t,x,indexing='ij')

x_test = X.reshape(-1,1)
t_test = T.reshape(-1,1)

with torch.no_grad():
    U = model(t_test, x_test)

U = U.reshape(nt,nx)

# %% [markdown]
# ## graph

# %%
plt.figure(figsize=(10,6))

plt.imshow(
    U,
    extent=[0,1,0,1],
    origin='lower',
    aspect='auto',
    cmap='jet'
)

plt.colorbar(label='Temperature')

plt.xlabel('x')

plt.ylabel('t')

plt.title('1D Heat Equation - PINN')

plt.savefig('2D.png')

plt.show()

# %% [markdown]
# # 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
nx = 100
nt = 100

x = torch.linspace(0,1,nx)

t = torch.linspace(0,1,nt)

T, X = torch.meshgrid(
    t,
    x,
    indexing='ij'
)

# %%
x_test = X.reshape(-1,1)

t_test = T.reshape(-1,1)

# %%
with torch.no_grad():

    U = model(
        t_test,
        x_test
    )

# %%
U = U.reshape(nt,nx)

U = U.numpy()

# %%
fig = plt.figure(figsize=(10,7))

ax = fig.add_subplot(
    111,
    projection='3d'
)

ax.set_xlabel('x')

ax.set_ylabel('t')

ax.set_zlabel('Temperature')

ax.set_title('PINN Solution of Heat Equation')

surf = ax.plot_surface(
    X.numpy(),
    T.numpy(),
    U,
    cmap='jet'
)

plt.savefig('3D.png')
